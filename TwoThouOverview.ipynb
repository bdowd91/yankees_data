# %%
# %matplotlib notebook

# %%
# dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# file 
file_path = "TwoThousandSeason.csv"

# Import data into a Pandas DataFrame
stats_df = pd.read_csv(file_path)
stats_df
# Out:
#           Date            Player          Position Throws    Bats        Type  \
# 0   12/13/1999    Brandon Knight    Relief Pitcher  Right    Left       Trade
# 1   12/13/1999      Sam Marsonek    Relief Pitcher  Right   Right       Trade
# 2   12/15/1999     Ryan Thompson        Outfielder  Right   Right  Free Agent
# 3   12/22/1999    Jake Westbrook    Relief Pitcher  Right   Right       Trade
# 4    1/26/2000     Roberto Kelly        Outfielder  Right   Right  Free Agent
# 5     2/1/2000        Tim Raines       Leftfielder  Right  Switch  Free Agent
# 6    3/17/2000         Ted Lilly  Starting Pitcher   Left    Left      Trade
# 7    3/22/2000  Christian Parker  Starting Pitcher  Right   Right       Trade
# 8     4/2/2000     Lance Johnson     Centerfielder   Left    Left  Free Agent
# 9     4/2/2000        Felix Jose      Rightfielder  Right  Switch  Free Agent
# 10    4/2/2000     Ryan Thompson        Outfielder  Right   Right    Released
# ...

# %%
stats_df["Type"].value_counts()
# Out:
# Trade         10
# Free Agent     9
# Released       1
# Trade          1
# Waivers        1
# Name: Type, dtype: int64

# %%
stats_df["Position"].value_counts()
# Out:
# Outfielder          6
# Starting Pitcher    4
# Relief Pitcher      3
# Centerfielder       2
# Rightfielder        2
# Infielder           2
# Leftfielder         2
# First Baseman       1
# Name: Position, dtype: int64

# %%
stats_df["Former Team"].value_counts()
# Out:
# Rangers      3
# Astros       3
# Expos        3
# Cubs         2
# Reds         2
# Rays         2
# Dodgers      1
# Indians      1
# Korea        1
# Braves       1
# Tigers       1
# Athletics    1
# Pirates      1
# Name: Former Team, dtype: int64
